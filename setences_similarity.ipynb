# %%
import os
import pickle
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from scipy.optimize import linear_sum_assignment
from tqdm import tqdm
from rich import print

# %% [markdown]
# ## Match doc & Similarirty functions

# %%
def match_two_docs(doc1, doc2):
    # pairwise distance between sentences
    sim = np.dot(doc1, doc2.T)
    sim = (sim + 1) / 2 #! why?
    # print(sim.shape, min(sim.shape))
    # assignment is to minimize the distance of matched sentences
    # WMD may be used here (to do)
    row_ind, col_ind = linear_sum_assignment(1 - sim)
    # print(row_ind)
    # print(col_ind)
    # total similarity of matched sentences
    score = sim[row_ind, col_ind].sum()
    # print(doc_sim)
    # normalize by min. size of two docs
    score1 = score / min(sim.shape)
    # normalize by max. size of two docs
    score2 = score / max(sim.shape)
    score = [score1, score2]
    return score, row_ind, col_ind, sim

def format_index_score(index_a, index_b, score, normalized_score, sim_shape):
    normalized_by_min, normalized_by_max = normalized_score
    return [[i, j, k, normalized_by_min, normalized_by_max, sim_shape] for i, j, k in zip(index_a, index_b, score)]

def compute_sim(df, bert_model, window=1):
    # ! cik: ?
    # * window: year interval
    result = {}
    years = np.sort(df.fyear.unique())
    embeddings = bert_model.encode(
        df.text.tolist(),
        convert_to_tensor=False,
        normalize_embeddings=True,
        convert_to_numpy=True,
    )
    for i in range(len(years) - 1):
        temp_dict = {}
        for j in range(i + 1, len(years)):
            if int(years[j].split('-Q')[1]) - int(years[i].split('-Q')[1]) <= window:
                doc1_index = df[df.fyear == years[i]].index.tolist()
                doc2_index = df[df.fyear == years[j]].index.tolist()
                doc1 = embeddings[doc1_index]
                doc2 = embeddings[doc2_index]
                score, row_ind, col_ind, sim = match_two_docs(doc1, doc2)
                # get matched pair similarity
                matched_sim = sim[row_ind, col_ind]
                temp_dict[years[j]] = format_index_score(row_ind, col_ind, matched_sim, score, sim.shape)
        result[years[i]] = temp_dict
    return result

# structure example
# m = {
#     "2017-Q1": {
#         "2017-Q2": [[0, 0, 0.5], [1, 9, 0.6]],
#         "2017-Q3": [[2, 8, 0.9], [10, 11, 0.12]],
#     },
#     "2017-Q2": {
#         "2017-Q1": [[13, 14, 0.15], [16, 17, 0.18]],
#         "2017-Q3": [[19, 20, 0.21], [22, 23, 0.24]],
#     },
# }

# post process funcs
def pair_dict(listOflist):
    temp_dict = {}
    for i in listOflist:
        pair_name = f'{str(i[0])}-{str(i[1])}'
        temp_dict[pair_name] = i[2:]
    return temp_dict

def post_process_df(m):
    # add another layer
    for key in m:
        cur_dict = m.get(key)
        for key2 in cur_dict.keys():
            cur_dict[key2] = pair_dict(cur_dict.get(key2))
    # prepare multi-index
    tuple_list = []
    for key in m:
        cur_dict = m.get(key)
        for key2 in cur_dict.keys():
            tuple_list.extend((key, key2, key3) for key3 in cur_dict.get(key2).keys())
    index = pd.MultiIndex.from_tuples(tuple_list, names=["Year1", "Year2", "MaxSim-Question-Pair"])
    # get similarity score
    similarity_score = []
    normalized_by_min = []
    normalized_by_max = []
    doc1_doc2_shape = []
    for key in m:
        cur_dict = m.get(key)
        for key2 in cur_dict.keys():
            for key3 in cur_dict.get(key2).keys():
                similarity_score.append(cur_dict.get(key2).get(key3)[0])
                normalized_by_min.append(cur_dict.get(key2).get(key3)[1])
                normalized_by_max.append(cur_dict.get(key2).get(key3)[2])
                doc1_doc2_shape.append(cur_dict.get(key2).get(key3)[3])
    return pd.DataFrame({'Similarity Score': similarity_score, 'Normalized_by_min': normalized_by_min, 'Normalized_by_max': normalized_by_max, 'Doc1_Doc2_shape': doc1_doc2_shape}, index=index)

# search text
def search_text(the_df, search_df):
    search_df = search_df.copy()
    the_df = the_df.copy()
    question_from_1 = []
    question_from_2 = []
    for index, row in tqdm(the_df.iterrows()):
        # unpack
        year1, year2, question_pair = index
        year1, year1_quater = year1.split("-")
        year2, year2_quater = year2.split("-")
        question_1_index, question_2_index = question_pair.split("-")
        # locate question 1
        year_filter = search_df['year'].apply(lambda x: x in [year1, int(year1)])
        question_1 = search_df[
            year_filter
            & (search_df["quater"] == year1_quater)
            & (search_df["question_index"] == int(question_1_index))
        ]["question"]
        question_from_1.append(question_1.iloc[0])
        # locate question 2
        year_filter = search_df['year'].apply(lambda x: x in [year2, int(year2)])
        question_2 = search_df[
            year_filter
            & (search_df["quater"] == year2_quater)
            & (search_df["question_index"] == int(question_2_index))
        ]["question"]
        question_from_2.append(question_2.iloc[0])
    the_df["Question_Year1"] = question_from_1
    the_df["Question_Year2"] = question_from_2
    
    return the_df

# %% [markdown]
# ## Format DF

# %%
setence_new_parsed = pd.read_csv(os.path.join(os.getcwd(), 'data', 'processed', 'Conf_transcripts_new_parsed_processed.csv'))
setence_new_parsed.head()
# Out:
# /tmp/ipykernel_2970/745358426.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   setence_new_parsed = pd.read_csv(os.path.join(os.getcwd(), 'data', 'processed', 'Conf_transcripts_new_parsed_processed.csv'))
#    question_index                          answeree  \
# 0               1  george paleologou, will kalutycz
# 1               2                     will kalutycz
# 2               3                     will kalutycz
# 3               5                 george paleologou
# 4               6                 george paleologou
#
#                                               answer     questioner  \
# 0  Yes, generally speaking, a lot of the rebalanc...   sabahat khan
# 1  Yes, it’s kind of a mixture, the Sandwich plan...   sabahat khan
# 2  Yes, again, I mean we deal in all commodities ...   sabahat khan
# 3                                     Thanks George.  george doumet
# 4  Yes, actually, it was more -- it was not too m...  george doumet
#
#                                             question  \
# 0  Thanks and good afternoon. Can you maybe talk ...
# 1  Alright, thanks. And then you mentioned that H...
# 2  Great. And then just if you could give us upda...
# 3  Hey, good afternoon guys and congrats on the q...
# 4  Just looking at Alberta first year-over-year g...
#
#                                            time_text equity quater  year
# 0  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017
# 1  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017
# 2  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017
# 3  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017
# 4  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017

# %% [markdown]
# ### AAPL

# %%
# years
np.sort(setence_new_parsed[setence_new_parsed['equity'] == 'AAPL'].year.unique())
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018], dtype=object)

# %%
# subset
filter_equity = setence_new_parsed['equity'] == 'AAPL'
aapl_raw = setence_new_parsed[filter_equity]
filter_year = aapl_raw['year'].apply(lambda x: x in ['2018', 2018])
filter_year_2 = aapl_raw['year'].apply(lambda x: x in ['2017', 2017])
final_filter = np.logical_or(filter_year, filter_year_2)
aapl_raw = aapl_raw[final_filter].copy()

# filter two short sentences
aapl_raw = aapl_raw[aapl_raw['question'].apply(lambda x: len(x.split()) > 5)]

# process index
for cur_query in tqdm(aapl_raw['time_text'].unique()):
    subset = aapl_raw[aapl_raw['time_text'] == cur_query]
    aapl_raw.loc[subset.index.tolist(), 'question_index'] = list(range(len(subset)))

print(aapl_raw['year'].unique())
print(aapl_raw['equity'].unique())
print(aapl_raw['quater'].unique())
aapl_raw.head(5)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 1273.16it/s]
# [2018 2017]
# ['AAPL']
# ['Q2' 'Q3' 'Q1' 'Q4']
#          question_index                           answeree  \
# 1857862               0  timothy donald cook - apple, inc.
# 1857863               1  timothy donald cook - apple, inc.
# 1857864               2  timothy donald cook - apple, inc.
# 1857865               3  timothy donald cook - apple, inc.
# 1857866               4  timothy donald cook - apple, inc.
#
#                                                     answer  \
# 1857862  Sure. Shannon, it's Tim. As Luca mentioned ear...
# 1857863  Hi, Katy. It's Tim. The services grew 31%. We ...
# 1857864  Yeah, I think my own view is that China and th...
# 1857865  Well, Mike, it's Tim. Again, the great thing a...
# 1857866  It's a good question. iPhone X was the most po...
#
#                                               questioner  \
# 1857862            shannon s. cross - cross research llc
# 1857863  kathryn lynn huberty - morgan stanley & co. llc
# 1857864  kathryn lynn huberty - morgan stanley & co. llc
# 1857865           michael j. olson - piper jaffray & co.
# 1857866           michael j. olson - piper jaffray & co.
#
#                                                   question  \
# 1857862  Thank you very much. I wanted to ask about you...
# 1857863  Thank you. Good afternoon. The services growth...
# 1857864  And it doesn't look like the threat of a trade...
# 1857865  Hey. Good afternoon, and thank you for taking ...
# 1857866  Okay. And then any potential tariff issues asi...
#
#                                                  time_text equity quater  year
# 1857862  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857863  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857864  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857865  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857866  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018

# %%
# format
aapl = pd.DataFrame(
    {
        "fyear": aapl_raw.apply(
            lambda x: str(x["year"]) + "-" + str(x["quater"]), axis=1
        ),
        "pid": aapl_raw["question_index"],
        "text": aapl_raw["question"],
    }
)
aapl.reset_index(drop=True, inplace=True)
aapl
# Out:
#       fyear  pid                                               text
# 0   2018-Q2    0  Thank you very much. I wanted to ask about you...
# 1   2018-Q2    1  Thank you. Good afternoon. The services growth...
# 2   2018-Q2    2  And it doesn't look like the threat of a trade...
# 3   2018-Q2    3  Hey. Good afternoon, and thank you for taking ...
# 4   2018-Q2    4  Okay. And then any potential tariff issues asi...
# ..      ...  ...                                                ...
# 56  2017-Q4   11     Thank you so much for your details. Thank you.
# 57  2017-Q4   12  Thanks a lot for taking my question, guys. I h...
# 58  2017-Q4   13  Got it. That's really helpful. And I guess if ...
# 59  2017-Q4   14  Yeah, Tim, I'm wondering if we take a look at ...
# 60  2017-Q4   15  And, Tim, it's interesting that sales grew 16%...
#
# [61 rows x 3 columns]

# %% [markdown]
# ### SKX

# %%
# years
np.sort(setence_new_parsed[setence_new_parsed['equity'] == 'SKX'].year.unique())
# Out:
# array(['2007', '2008', '2009', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018'], dtype=object)

# %%
# subset
filter_equity = setence_new_parsed['equity'] == 'SKX'
skx_raw = setence_new_parsed[filter_equity].copy()
filter_year = skx_raw['year'].apply(lambda x: x in ['2018', 2018])
filter_year_2 = skx_raw['year'].apply(lambda x: x in ['2017', 2017])
final_filter = np.logical_or(filter_year, filter_year_2)
skx_raw = skx_raw[final_filter].copy()


# filter two short sentences
skx_raw = skx_raw[skx_raw['question'].apply(lambda x: len(x.split()) > 5)]

# process index
# for cur_query in tqdm(skx_raw['time_text'].unique()):
#     subset = skx_raw[skx_raw['time_text'] == cur_query]
#     skx_raw.loc[subset.index.tolist(), 'question_index'] = list(range(len(subset)))
for cur_query in tqdm(skx_raw['year'].unique()):
    subset1 = skx_raw[skx_raw['year'] == cur_query]
    for cur_query2 in subset1['quater'].unique():
        subset2 = subset1[subset1['quater'] == cur_query2]
        skx_raw.loc[subset2.index.tolist(), 'question_index'] = list(range(len(subset2)))

print(skx_raw['year'].unique())
print(skx_raw['equity'].unique())
print(skx_raw['quater'].unique())
print(len(skx_raw))
skx_raw.head(5)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 416.83it/s]
# ['2017' '2018']
# ['SKX']
# ['Q1' 'Q2' 'Q4' 'Q3']
# 262
#       question_index        answeree  \
# 2825               0  david weinberg
# 2826               1  david weinberg
# 2827               2  david weinberg
# 2828               3  david weinberg
# 2829               4  david weinberg
#
#                                                  answer     questioner  \
# 2825                            Hey Scott, pretty good.   scott krasik
# 2826  Well, those -- all those items you mentioned, ...   scott krasik
# 2827  Yes, I think it's fair to say the new product ...   scott krasik
# 2828                                            Thanks.   scott krasik
# 2829                                         Thank you.  david buckley
#
#                                                question  \
# 2825                      Hey David, how are you doing?
# 2826  Good job. So, two questions here. First, just ...
# 2827  And as you look -- I mean are you assuming tha...
# 2828          Okay. Awesome. Thanks so much. Good luck.
# 2829  Hi, this is David Buckley on for John Kernan. ...
#
#                                               time_text equity quater  year
# 2825  SKECHERS USA, Inc. (NYSE:SKX)Q1 2017 Results E...    SKX     Q1  2017
# 2826  SKECHERS USA, Inc. (NYSE:SKX)Q1 2017 Results E...    SKX     Q1  2017
# 2827  SKECHERS USA, Inc. (NYSE:SKX)Q1 2017 Results E...    SKX     Q1  2017
# 2828  SKECHERS USA, Inc. (NYSE:SKX)Q1 2017 Results E...    SKX     Q1  2017
# 2829  SKECHERS USA, Inc. (NYSE:SKX)Q1 2017 Results E...    SKX     Q1  2017

# %%
# format
skx = pd.DataFrame(
    {
        "fyear": skx_raw.apply(
            lambda x: str(x["year"]) + "-" + str(x["quater"]), axis=1
        ),
        "pid": skx_raw["question_index"],
        "text": skx_raw["question"],
    }
)
skx.reset_index(drop=True, inplace=True)
skx
# Out:
#        fyear  pid                                               text
# 0    2017-Q1    0                      Hey David, how are you doing?
# 1    2017-Q1    1  Good job. So, two questions here. First, just ...
# 2    2017-Q1    2  And as you look -- I mean are you assuming tha...
# 3    2017-Q1    3          Okay. Awesome. Thanks so much. Good luck.
# 4    2017-Q1    4  Hi, this is David Buckley on for John Kernan. ...
# ..       ...  ...                                                ...
# 257  2018-Q1   33  And are you seeing a similar mix in your own s...
# 258  2018-Q1   34  And as far as visibility in the second quarter...
# 259  2018-Q1   35  Yes, of course. And then your own retail store...
# 260  2018-Q1   36  Right and of course. And just one more. In loo...
# 261  2018-Q1   37              Okay. Thank you very much. Good luck.
#
# [262 rows x 3 columns]

# %% [markdown]
# ## Model

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ## Compute Similarity

# %% [markdown]
# ### AAPL

# %%
aapl_sim = compute_sim(aapl, model, window=10)
aapl_sim = post_process_df(aapl_sim)
aapl_sim = search_text(aapl_sim, aapl_raw)

aapl_sim
# Out:
# 100it [00:00, 739.09it/s]
#                                       Similarity Score  Normalized_by_min  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q3 0-0                           0.826229           0.807500
#                 1-8                           0.841549           0.807500
#                 2-6                           0.803858           0.807500
#                 3-2                           0.818691           0.807500
#                 4-1                           0.828638           0.807500
# ...                                                ...                ...
# 2018-Q1 2018-Q2 6-9                           0.778559           0.745475
#                 7-1                           0.722830           0.745475
#                 10-7                          0.694836           0.745475
#                 14-4                          0.925555           0.745475
#                 15-6                          0.709624           0.745475
#
#                                       Normalized_by_max Doc1_Doc2_shape  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q3 0-0                            0.646000         (8, 10)
#                 1-8                            0.646000         (8, 10)
#                 2-6                            0.646000         (8, 10)
#                 3-2                            0.646000         (8, 10)
#                 4-1                            0.646000         (8, 10)
# ...                                                 ...             ...
# 2018-Q1 2018-Q2 6-9                            0.512514        (16, 11)
#                 7-1                            0.512514        (16, 11)
#                 10-7                           0.512514        (16, 11)
#                 14-4                           0.512514        (16, 11)
#                 15-6                           0.512514        (16, 11)
#
#                                                                          Question_Year1  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q3 0-0                   Yes, thank you. First, Luca, what are the fact...
#                 1-8                   Amit Daryanani - RBC Capital Markets LLC', 'Th...
#                 2-6                   Luca, I'm wondering if you could talk a little...
#                 3-2                   Hi, thank you. I wanted to dig in a little bit...
#                 4-1                   Thank you, and then just one follow-up on Chin...
# ...                                                                                 ...
# 2018-Q1 2018-Q2 6-9                   I have a question and follow-up. You commented...
#                 7-1                   And just a follow-up, maybe I could clarify tw...
#                 10-7                  Yes, I was asking as a percent, the ownership....
#                 14-4                  I have two questions as well. I guess first on...
#                 15-6                  Luca, maybe a question for you. When you talke...
#
#                                                                          Question_Year2
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q3 0-0                   Yes, thanks. Good afternoon. Luca, first quest...
#                 1-8                   Thanks a lot. Good afternoon, guys. I guess to...
#                 2-6                   Yes, thank you. I have one for Luca and one fo...
#                 3-2                   Great. Thank you. And then can you talk a bit ...
#                 4-1                   Thank you very much for taking my question. Ti...
# ...                                                                                 ...
# 2018-Q1 2018-Q2 6-9                   Thank you very much. And I'll ask actually bot...
#                 7-1                   Thank you. Good afternoon. The services growth...
#                 10-7                  Yes, Tim, I think there is China numbers are a...
#                 14-4                  Okay. And then any potential tariff issues asi...
#                 15-6                  Great. Thank you. Luca, could you talk a bit m...
#
# [100 rows x 6 columns]

# %% [markdown]
# ### SKX

# %%
skx_sim = compute_sim(skx, model, window=10)
skx_sim = post_process_df(skx_sim)
skx_sim = search_text(skx_sim, skx_raw)

skx_sim
# Out:
# 431it [00:00, 719.95it/s]
#                                       Similarity Score  Normalized_by_min  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q2 0-0                           0.834134           0.753525
#                 1-14                          0.792789           0.753525
#                 2-39                          0.789668           0.753525
#                 3-38                          0.639594           0.753525
#                 4-5                           0.666190           0.753525
# ...                                                ...                ...
# 2017-Q4 2018-Q1 42-31                         0.980718           0.778037
#                 43-11                         0.926188           0.778037
#                 44-12                         0.731424           0.778037
#                 46-36                         0.728796           0.778037
#                 49-29                         0.689818           0.778037
#
#                                       Normalized_by_max Doc1_Doc2_shape  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q2 0-0                            0.395600        (42, 80)
#                 1-14                           0.395600        (42, 80)
#                 2-39                           0.395600        (42, 80)
#                 3-38                           0.395600        (42, 80)
#                 4-5                            0.395600        (42, 80)
# ...                                                 ...             ...
# 2017-Q4 2018-Q1 42-31                          0.579714        (51, 38)
#                 43-11                          0.579714        (51, 38)
#                 44-12                          0.579714        (51, 38)
#                 46-36                          0.579714        (51, 38)
#                 49-29                          0.579714        (51, 38)
#
#                                                                          Question_Year1  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q2 0-0                                       Hey David, how are you doing?
#                 1-14                  Good job. So, two questions here. First, just ...
#                 2-39                  And as you look -- I mean are you assuming tha...
#                 3-38                          Okay. Awesome. Thanks so much. Good luck.
#                 4-5                   Hi, this is David Buckley on for John Kernan. ...
# ...                                                                                 ...
# 2017-Q4 2018-Q1 42-31                        All right. Thanks very much. Best of luck.
#                 43-11                    Good afternoon. Thanks for taking my question.
#                 44-12                 Hi. I just wanted to touch on some of the newe...
#                 46-36                 Hey, thanks for fitting me back in. Just a cou...
#                 49-29                 But I'm referring to how it comes against purc...
#
#                                                                          Question_Year2
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q2 0-0                   Hey, David. How are you doing? Congrats on a b...
#                 1-14                  Good afternoon, David. Thanks for taking my qu...
#                 2-39                  Okay. And then I think you see more spring 201...
#                 3-38                  Okay. And then the price increase went through...
#                 4-5                   Good afternoon, David. Thanks for taking my qu...
# ...                                                                                 ...
# 2017-Q4 2018-Q1 42-31                               All right. Thanks and best of luck.
#                 43-11                 Hi. Good afternoon everybody. Thanks for takin...
#                 44-12                 I think the SG&A dollar growth is obviously a ...
#                 46-36                 Right and of course. And just one more. In loo...
#                 49-29                    So that you will leverage distribution better?
#
# [431 rows x 6 columns]

# %%
skx_sim.loc['2017-Q1']
# Out:
#                               Similarity Score  Normalized_by_min  \
# Year2   MaxSim-Question-Pair
# 2017-Q2 0-0                           0.834134           0.753525
#         1-14                          0.792789           0.753525
#         2-39                          0.789668           0.753525
#         3-38                          0.639594           0.753525
#         4-5                           0.666190           0.753525
# ...                                        ...                ...
# 2018-Q1 35-36                         0.769019           0.745954
#         36-18                         0.814759           0.745954
#         37-26                         0.706237           0.745954
#         38-23                         0.719074           0.745954
#         40-29                         0.612309           0.745954
#
#                               Normalized_by_max Doc1_Doc2_shape  \
# Year2   MaxSim-Question-Pair
# 2017-Q2 0-0                            0.395600        (42, 80)
#         1-14                           0.395600        (42, 80)
#         2-39                           0.395600        (42, 80)
#         3-38                           0.395600        (42, 80)
#         4-5                            0.395600        (42, 80)
# ...                                         ...             ...
# 2018-Q1 35-36                          0.674911        (42, 38)
#         36-18                          0.674911        (42, 38)
#         37-26                          0.674911        (42, 38)
#         38-23                          0.674911        (42, 38)
#         40-29                          0.674911        (42, 38)
#
#                                                                  Question_Year1  \
# Year2   MaxSim-Question-Pair
# 2017-Q2 0-0                                       Hey David, how are you doing?
#         1-14                  Good job. So, two questions here. First, just ...
#         2-39                  And as you look -- I mean are you assuming tha...
#         3-38                          Okay. Awesome. Thanks so much. Good luck.
#         4-5                   Hi, this is David Buckley on for John Kernan. ...
# ...                                                                         ...
# 2018-Q1 35-36                 Hi David. I wonder if you can just maybe give ...
#         36-18                 Okay. Understood. And then not to beat a dead ...
#         37-26                 Okay, good. And then one final one. Just on Ca...
#         38-23                 Hey David. Thanks for squeezing me in. Just wa...
#         40-29                 Okay, perfect. And then just last can you give...
#
#                                                                  Question_Year2
# Year2   MaxSim-Question-Pair
# 2017-Q2 0-0                   Hey, David. How are you doing? Congrats on a b...
#         1-14                  Good afternoon, David. Thanks for taking my qu...
#         2-39                  Okay. And then I think you see more spring 201...
#         3-38                  Okay. And then the price increase went through...
#         4-5                   Good afternoon, David. Thanks for taking my qu...
# ...                                                                         ...
# 2018-Q1 35-36                 Right and of course. And just one more. In loo...
#         36-18                 Thank you for taking my questions. Good aftern...
#         37-26                 Should we think about that number as like in t...
#         38-23                 Okay. Great. And then just a follow-up on Tom'...
#         40-29                    So that you will leverage distribution better?
#
# [164 rows x 6 columns]

# %% [markdown]
# ## Save Results

# %%
# save aapl
with open(os.path.join(os.getcwd(), 'data', 'result', 'aapl_sim.pkl'), 'wb') as f:
    pickle.dump(aapl_sim, f)
    
# save skx
with open(os.path.join(os.getcwd(), 'data', 'result', 'skx_sim.pkl'), 'wb') as f:
    pickle.dump(skx_sim, f)

# %%
# test load
with open(os.path.join(os.getcwd(), 'data', 'result', 'aapl_sim.pkl'), 'rb') as f:
    aapl_test = pickle.load(f)
aapl_test
# Out:
#                                       Similarity Score  Normalized_by_min  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q3 0-0                           0.826229           0.807500
#                 1-8                           0.841549           0.807500
#                 2-6                           0.803858           0.807500
#                 3-2                           0.818691           0.807500
#                 4-1                           0.828638           0.807500
# ...                                                ...                ...
# 2018-Q1 2018-Q2 6-9                           0.778559           0.745475
#                 7-1                           0.722830           0.745475
#                 10-7                          0.694836           0.745475
#                 14-4                          0.925555           0.745475
#                 15-6                          0.709624           0.745475
#
#                                       Normalized_by_max Doc1_Doc2_shape  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q3 0-0                            0.646000         (8, 10)
#                 1-8                            0.646000         (8, 10)
#                 2-6                            0.646000         (8, 10)
#                 3-2                            0.646000         (8, 10)
#                 4-1                            0.646000         (8, 10)
# ...                                                 ...             ...
# 2018-Q1 2018-Q2 6-9                            0.512514        (16, 11)
#                 7-1                            0.512514        (16, 11)
#                 10-7                           0.512514        (16, 11)
#                 14-4                           0.512514        (16, 11)
#                 15-6                           0.512514        (16, 11)
#
#                                                                          Question_Year1  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q3 0-0                   Yes, thank you. First, Luca, what are the fact...
#                 1-8                   Amit Daryanani - RBC Capital Markets LLC', 'Th...
#                 2-6                   Luca, I'm wondering if you could talk a little...
#                 3-2                   Hi, thank you. I wanted to dig in a little bit...
#                 4-1                   Thank you, and then just one follow-up on Chin...
# ...                                                                                 ...
# 2018-Q1 2018-Q2 6-9                   I have a question and follow-up. You commented...
#                 7-1                   And just a follow-up, maybe I could clarify tw...
#                 10-7                  Yes, I was asking as a percent, the ownership....
#                 14-4                  I have two questions as well. I guess first on...
#                 15-6                  Luca, maybe a question for you. When you talke...
#
#                                                                          Question_Year2
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q3 0-0                   Yes, thanks. Good afternoon. Luca, first quest...
#                 1-8                   Thanks a lot. Good afternoon, guys. I guess to...
#                 2-6                   Yes, thank you. I have one for Luca and one fo...
#                 3-2                   Great. Thank you. And then can you talk a bit ...
#                 4-1                   Thank you very much for taking my question. Ti...
# ...                                                                                 ...
# 2018-Q1 2018-Q2 6-9                   Thank you very much. And I'll ask actually bot...
#                 7-1                   Thank you. Good afternoon. The services growth...
#                 10-7                  Yes, Tim, I think there is China numbers are a...
#                 14-4                  Okay. And then any potential tariff issues asi...
#                 15-6                  Great. Thank you. Luca, could you talk a bit m...
#
# [100 rows x 6 columns]

# %%
aapl_test.loc['2017-Q1']
# Out:
#                               Similarity Score  Normalized_by_min  \
# Year2   MaxSim-Question-Pair
# 2017-Q3 0-0                           0.826229           0.807500
#         1-8                           0.841549           0.807500
#         2-6                           0.803858           0.807500
#         3-2                           0.818691           0.807500
#         4-1                           0.828638           0.807500
#         5-5                           0.899853           0.807500
#         6-7                           0.655626           0.807500
#         7-9                           0.785555           0.807500
# 2017-Q4 0-0                           0.740561           0.789106
#         1-13                          0.813766           0.789106
#         2-12                          0.789158           0.789106
#         3-14                          0.806137           0.789106
#         4-1                           0.888874           0.789106
#         5-6                           0.792573           0.789106
#         6-10                          0.708665           0.789106
#         7-9                           0.773118           0.789106
# 2018-Q1 0-3                           0.774480           0.788081
#         1-12                          0.733978           0.788081
#         2-2                           0.758016           0.788081
#         3-1                           0.712672           0.788081
#         4-14                          0.903954           0.788081
#         5-6                           0.923234           0.788081
#         6-5                           0.694952           0.788081
#         7-4                           0.803359           0.788081
# 2018-Q2 0-5                           0.811439           0.796201
#         1-1                           0.759700           0.796201
#         2-9                           0.850396           0.796201
#         3-4                           0.808617           0.796201
#         4-7                           0.901424           0.796201
#         5-0                           0.814872           0.796201
#         6-8                           0.704262           0.796201
#         7-3                           0.718899           0.796201
#
#                               Normalized_by_max Doc1_Doc2_shape  \
# Year2   MaxSim-Question-Pair
# 2017-Q3 0-0                            0.646000         (8, 10)
#         1-8                            0.646000         (8, 10)
#         2-6                            0.646000         (8, 10)
#         3-2                            0.646000         (8, 10)
#         4-1                            0.646000         (8, 10)
#         5-5                            0.646000         (8, 10)
#         6-7                            0.646000         (8, 10)
#         7-9                            0.646000         (8, 10)
# 2017-Q4 0-0                            0.394553         (8, 16)
#         1-13                           0.394553         (8, 16)
#         2-12                           0.394553         (8, 16)
#         3-14                           0.394553         (8, 16)
#         4-1                            0.394553         (8, 16)
#         5-6                            0.394553         (8, 16)
#         6-10                           0.394553         (8, 16)
#         7-9                            0.394553         (8, 16)
# 2018-Q1 0-3                            0.394040         (8, 16)
#         1-12                           0.394040         (8, 16)
#         2-2                            0.394040         (8, 16)
#         3-1                            0.394040         (8, 16)
#         4-14                           0.394040         (8, 16)
#         5-6                            0.394040         (8, 16)
#         6-5                            0.394040         (8, 16)
#         7-4                            0.394040         (8, 16)
# 2018-Q2 0-5                            0.579055         (8, 11)
#         1-1                            0.579055         (8, 11)
#         2-9                            0.579055         (8, 11)
#         3-4                            0.579055         (8, 11)
#         4-7                            0.579055         (8, 11)
#         5-0                            0.579055         (8, 11)
#         6-8                            0.579055         (8, 11)
#         7-3                            0.579055         (8, 11)
#
#                                                                  Question_Year1  \
# Year2   MaxSim-Question-Pair
# 2017-Q3 0-0                   Yes, thank you. First, Luca, what are the fact...
#         1-8                   Amit Daryanani - RBC Capital Markets LLC', 'Th...
#         2-6                   Luca, I'm wondering if you could talk a little...
#         3-2                   Hi, thank you. I wanted to dig in a little bit...
#         4-1                   Thank you, and then just one follow-up on Chin...
#         5-5                   Yes, thank you. I just wanted to better unders...
#         6-7                   Thank you. First, I wanted to ask about the iP...
#         7-9                   Okay, that's great, thank you. And then, Tim, ...
# 2017-Q4 0-0                   Yes, thank you. First, Luca, what are the fact...
#         1-13                  Amit Daryanani - RBC Capital Markets LLC', 'Th...
#         2-12                  Luca, I'm wondering if you could talk a little...
#         3-14                  Hi, thank you. I wanted to dig in a little bit...
#         4-1                   Thank you, and then just one follow-up on Chin...
#         5-6                   Yes, thank you. I just wanted to better unders...
#         6-10                  Thank you. First, I wanted to ask about the iP...
#         7-9                   Okay, that's great, thank you. And then, Tim, ...
# 2018-Q1 0-3                   Yes, thank you. First, Luca, what are the fact...
#         1-12                  Amit Daryanani - RBC Capital Markets LLC', 'Th...
#         2-2                   Luca, I'm wondering if you could talk a little...
#         3-1                   Hi, thank you. I wanted to dig in a little bit...
#         4-14                  Thank you, and then just one follow-up on Chin...
#         5-6                   Yes, thank you. I just wanted to better unders...
#         6-5                   Thank you. First, I wanted to ask about the iP...
#         7-4                   Okay, that's great, thank you. And then, Tim, ...
# 2018-Q2 0-5                   Yes, thank you. First, Luca, what are the fact...
#         1-1                   Amit Daryanani - RBC Capital Markets LLC', 'Th...
#         2-9                   Luca, I'm wondering if you could talk a little...
#         3-4                   Hi, thank you. I wanted to dig in a little bit...
#         4-7                   Thank you, and then just one follow-up on Chin...
#         5-0                   Yes, thank you. I just wanted to better unders...
#         6-8                   Thank you. First, I wanted to ask about the iP...
#         7-3                   Okay, that's great, thank you. And then, Tim, ...
#
#                                                                  Question_Year2
# Year2   MaxSim-Question-Pair
# 2017-Q3 0-0                   Yes, thanks. Good afternoon. Luca, first quest...
#         1-8                   Thanks a lot. Good afternoon, guys. I guess to...
#         2-6                   Yes, thank you. I have one for Luca and one fo...
#         3-2                   Great. Thank you. And then can you talk a bit ...
#         4-1                   Thank you very much for taking my question. Ti...
#         5-5                   Thank you, a question for Tim maybe on the iPh...
#         6-7                   Good afternoon. I just have one question for T...
#         7-9                   Yes. Tim, growth in the smartphone market is n...
# 2017-Q4 0-0                   Thank you. Congrats on the quarter. Luca, when...
#         1-13                  Got it. That's really helpful. And I guess if ...
#         2-12                  Thanks a lot for taking my question, guys. I h...
#         3-14                  Yeah, Tim, I'm wondering if we take a look at ...
#         4-1                   Okay. And then China growth returned to strong...
#         5-6                   Thank you. I wanted to try to push a little bi...
#         6-10                  Thanks very much. And I'll ask my original que...
#         7-9                   Okay. Thank you for that. And then I wanted to...
# 2018-Q1 0-3                   Yes, that's great color. Just a follow-up on g...
#         1-12                  Tim, you said you don't want to tell investors...
#         2-2                   Growing double-digits of such a large revenue ...
#         3-1                   And then, Tim, maybe could you talk a little b...
#         4-14                  I have two questions as well. I guess first on...
#         5-6                   I have a question and follow-up. You commented...
#         6-5                   And then how you're think about AR beyond iPho...
#         7-4                   I know you don't talk about future products, w...
# 2018-Q2 0-5                   Thanks a lot. Two questions from me as well. I...
#         1-1                   Thank you. Good afternoon. The services growth...
#         2-9                   Thank you very much. And I'll ask actually bot...
#         3-4                   Okay. And then any potential tariff issues asi...
#         4-7                   Yes, Tim, I think there is China numbers are a...
#         5-0                   Thank you very much. I wanted to ask about you...
#         6-8                   Wamsi Mohan - Bank of America Merrill Lynch', ...
#         7-3                   Hey. Good afternoon, and thank you for taking ...

# %%
aapl_test.loc['2017-Q1', '2017-Q3', '3-2']['Question_Year1']
# Out:
# 'Hi, thank you. I wanted to dig in a little bit more into the iPhone upside in the quarter with record revenues in every region except for Greater China. I think you touched on the percent of switchers in China. But can you give a little more color on the split of upgrades and switchers in some of the other regions and overall as well?'

# %%
aapl_test.loc['2017-Q1', '2017-Q3', '3-2']['Question_Year2']
# Out:
# "Great. Thank you. And then can you talk a bit about the composition of the installed base of iPhones at this point, as obviously we're getting close to a refresh? Just you brought in the iPhone SE. You've obviously had strength at the high end. I'm just trying to think about what percent do you think have upgraded in the prior generation, any color you can give us on that?"

# %%
aapl_test.loc['2017-Q1', '2018-Q2', '4-7']['Question_Year1']
# Out:
# "Thank you, and then just one follow-up on China specifically. As your comps get easier this year, I was curious if you think you're going to be returning to growth in that region. And then just to give us the context, I know you talked about the 6% constant currency increase in revenue in Mainland China. But curious if you strip out the double-digit increase in iPad and MacBook and potentially the mix shift to the iPhone 7 Plus, I'm curious what underlying iPhone units did in Mainland China."

# %%
aapl_test.loc['2017-Q1', '2018-Q2', '4-7']['Question_Year2']
# Out:
# "Yes, Tim, I think there is China numbers are actually phenomenal in the quarter and third consecutive quarter of growth. I think there's been a lot of concerns just Apple in China and maybe misinformation out there. But what do you see as the drivers for Apple in both Mainland China and Greater China over the next few years? And also if you could just give us an update on what you're seeing in India."

# %%
# test load
with open(os.path.join(os.getcwd(), 'data', 'result', 'skx_sim.pkl'), 'rb') as f:
    skx_test = pickle.load(f)
skx_test
# Out:
#                                       Similarity Score  Normalized_by_min  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q2 0-0                           0.834134           0.753525
#                 1-14                          0.792789           0.753525
#                 2-39                          0.789668           0.753525
#                 3-38                          0.639594           0.753525
#                 4-5                           0.666190           0.753525
# ...                                                ...                ...
# 2017-Q4 2018-Q1 42-31                         0.980718           0.778037
#                 43-11                         0.926188           0.778037
#                 44-12                         0.731424           0.778037
#                 46-36                         0.728796           0.778037
#                 49-29                         0.689818           0.778037
#
#                                       Normalized_by_max Doc1_Doc2_shape  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q2 0-0                            0.395600        (42, 80)
#                 1-14                           0.395600        (42, 80)
#                 2-39                           0.395600        (42, 80)
#                 3-38                           0.395600        (42, 80)
#                 4-5                            0.395600        (42, 80)
# ...                                                 ...             ...
# 2017-Q4 2018-Q1 42-31                          0.579714        (51, 38)
#                 43-11                          0.579714        (51, 38)
#                 44-12                          0.579714        (51, 38)
#                 46-36                          0.579714        (51, 38)
#                 49-29                          0.579714        (51, 38)
#
#                                                                          Question_Year1  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q2 0-0                                       Hey David, how are you doing?
#                 1-14                  Good job. So, two questions here. First, just ...
#                 2-39                  And as you look -- I mean are you assuming tha...
#                 3-38                          Okay. Awesome. Thanks so much. Good luck.
#                 4-5                   Hi, this is David Buckley on for John Kernan. ...
# ...                                                                                 ...
# 2017-Q4 2018-Q1 42-31                        All right. Thanks very much. Best of luck.
#                 43-11                    Good afternoon. Thanks for taking my question.
#                 44-12                 Hi. I just wanted to touch on some of the newe...
#                 46-36                 Hey, thanks for fitting me back in. Just a cou...
#                 49-29                 But I'm referring to how it comes against purc...
#
#                                                                          Question_Year2
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q1 2017-Q2 0-0                   Hey, David. How are you doing? Congrats on a b...
#                 1-14                  Good afternoon, David. Thanks for taking my qu...
#                 2-39                  Okay. And then I think you see more spring 201...
#                 3-38                  Okay. And then the price increase went through...
#                 4-5                   Good afternoon, David. Thanks for taking my qu...
# ...                                                                                 ...
# 2017-Q4 2018-Q1 42-31                               All right. Thanks and best of luck.
#                 43-11                 Hi. Good afternoon everybody. Thanks for takin...
#                 44-12                 I think the SG&A dollar growth is obviously a ...
#                 46-36                 Right and of course. And just one more. In loo...
#                 49-29                    So that you will leverage distribution better?
#
# [431 rows x 6 columns]

# %%
skx_test.loc['2017-Q1']
# Out:
#                               Similarity Score  Normalized_by_min  \
# Year2   MaxSim-Question-Pair
# 2017-Q2 0-0                           0.834134           0.753525
#         1-14                          0.792789           0.753525
#         2-39                          0.789668           0.753525
#         3-38                          0.639594           0.753525
#         4-5                           0.666190           0.753525
# ...                                        ...                ...
# 2018-Q1 35-36                         0.769019           0.745954
#         36-18                         0.814759           0.745954
#         37-26                         0.706237           0.745954
#         38-23                         0.719074           0.745954
#         40-29                         0.612309           0.745954
#
#                               Normalized_by_max Doc1_Doc2_shape  \
# Year2   MaxSim-Question-Pair
# 2017-Q2 0-0                            0.395600        (42, 80)
#         1-14                           0.395600        (42, 80)
#         2-39                           0.395600        (42, 80)
#         3-38                           0.395600        (42, 80)
#         4-5                            0.395600        (42, 80)
# ...                                         ...             ...
# 2018-Q1 35-36                          0.674911        (42, 38)
#         36-18                          0.674911        (42, 38)
#         37-26                          0.674911        (42, 38)
#         38-23                          0.674911        (42, 38)
#         40-29                          0.674911        (42, 38)
#
#                                                                  Question_Year1  \
# Year2   MaxSim-Question-Pair
# 2017-Q2 0-0                                       Hey David, how are you doing?
#         1-14                  Good job. So, two questions here. First, just ...
#         2-39                  And as you look -- I mean are you assuming tha...
#         3-38                          Okay. Awesome. Thanks so much. Good luck.
#         4-5                   Hi, this is David Buckley on for John Kernan. ...
# ...                                                                         ...
# 2018-Q1 35-36                 Hi David. I wonder if you can just maybe give ...
#         36-18                 Okay. Understood. And then not to beat a dead ...
#         37-26                 Okay, good. And then one final one. Just on Ca...
#         38-23                 Hey David. Thanks for squeezing me in. Just wa...
#         40-29                 Okay, perfect. And then just last can you give...
#
#                                                                  Question_Year2
# Year2   MaxSim-Question-Pair
# 2017-Q2 0-0                   Hey, David. How are you doing? Congrats on a b...
#         1-14                  Good afternoon, David. Thanks for taking my qu...
#         2-39                  Okay. And then I think you see more spring 201...
#         3-38                  Okay. And then the price increase went through...
#         4-5                   Good afternoon, David. Thanks for taking my qu...
# ...                                                                         ...
# 2018-Q1 35-36                 Right and of course. And just one more. In loo...
#         36-18                 Thank you for taking my questions. Good aftern...
#         37-26                 Should we think about that number as like in t...
#         38-23                 Okay. Great. And then just a follow-up on Tom'...
#         40-29                    So that you will leverage distribution better?
#
# [164 rows x 6 columns]

# %%
skx_test.loc['2017-Q1', '2017-Q2', '1-14']['Question_Year1']
# Out:
# "Good job. So, two questions here. First, just trying to understand the backlog, maybe how do we think about mid-single-digits, I guess domestically, I think it was a mid to high single at the end of the year and clearly you're not guiding to that level of growth. So, what's assumed in your flat to up low single-digit growth for the second quarter? Is it much more weighted to 3Q? Does it depend on how back-to-school ships? And then how are the new products sort of built in to that?"

# %%
skx_test.loc['2017-Q1', '2017-Q2', '1-14']['Question_Year2']
# Out:
# 'Good afternoon, David. Thanks for taking my question. I want to follow-up on the domestic wholesale guide for the third quarter. Can you potentially qualify in dollar terms how much was shifted from 3Q into 2Q? And is there any potential pull-forward from 4Q into 3Q that we should consider for this year?'

# %%
skx_test.loc['2017-Q4']
# Out:
#                               Similarity Score  Normalized_by_min  \
# Year2   MaxSim-Question-Pair
# 2018-Q1 1-21                          0.786189           0.778037
#         2-34                          0.674866           0.778037
#         3-14                          0.808947           0.778037
#         4-8                           0.805140           0.778037
#         6-19                          0.702720           0.778037
#         7-26                          0.739748           0.778037
#         8-15                          0.872132           0.778037
#         9-9                           0.771075           0.778037
#         10-32                         0.803740           0.778037
#         11-37                         0.933767           0.778037
#         12-25                         0.700450           0.778037
#         14-33                         0.638711           0.778037
#         15-2                          0.661857           0.778037
#         16-28                         0.658384           0.778037
#         19-17                         0.838586           0.778037
#         20-30                         0.858042           0.778037
#         22-18                         0.775346           0.778037
#         23-4                          0.830006           0.778037
#         24-0                          0.728952           0.778037
#         25-35                         0.687867           0.778037
#         26-22                         0.805144           0.778037
#         27-23                         0.777475           0.778037
#         28-7                          0.767266           0.778037
#         29-24                         0.868469           0.778037
#         32-27                         0.766757           0.778037
#         33-20                         0.622383           0.778037
#         35-5                          0.776119           0.778037
#         36-1                          0.735395           0.778037
#         37-6                          0.799449           0.778037
#         38-13                         0.749473           0.778037
#         39-10                         0.981586           0.778037
#         40-16                         0.837868           0.778037
#         41-3                          0.744536           0.778037
#         42-31                         0.980718           0.778037
#         43-11                         0.926188           0.778037
#         44-12                         0.731424           0.778037
#         46-36                         0.728796           0.778037
#         49-29                         0.689818           0.778037
#
#                               Normalized_by_max Doc1_Doc2_shape  \
# Year2   MaxSim-Question-Pair
# 2018-Q1 1-21                           0.579714        (51, 38)
#         2-34                           0.579714        (51, 38)
#         3-14                           0.579714        (51, 38)
#         4-8                            0.579714        (51, 38)
#         6-19                           0.579714        (51, 38)
#         7-26                           0.579714        (51, 38)
#         8-15                           0.579714        (51, 38)
#         9-9                            0.579714        (51, 38)
#         10-32                          0.579714        (51, 38)
#         11-37                          0.579714        (51, 38)
#         12-25                          0.579714        (51, 38)
#         14-33                          0.579714        (51, 38)
#         15-2                           0.579714        (51, 38)
#         16-28                          0.579714        (51, 38)
#         19-17                          0.579714        (51, 38)
#         20-30                          0.579714        (51, 38)
#         22-18                          0.579714        (51, 38)
#         23-4                           0.579714        (51, 38)
#         24-0                           0.579714        (51, 38)
#         25-35                          0.579714        (51, 38)
#         26-22                          0.579714        (51, 38)
#         27-23                          0.579714        (51, 38)
#         28-7                           0.579714        (51, 38)
#         29-24                          0.579714        (51, 38)
#         32-27                          0.579714        (51, 38)
#         33-20                          0.579714        (51, 38)
#         35-5                           0.579714        (51, 38)
#         36-1                           0.579714        (51, 38)
#         37-6                           0.579714        (51, 38)
#         38-13                          0.579714        (51, 38)
#         39-10                          0.579714        (51, 38)
#         40-16                          0.579714        (51, 38)
#         41-3                           0.579714        (51, 38)
#         42-31                          0.579714        (51, 38)
#         43-11                          0.579714        (51, 38)
#         44-12                          0.579714        (51, 38)
#         46-36                          0.579714        (51, 38)
#         49-29                          0.579714        (51, 38)
#
#                                                                  Question_Year1  \
# Year2   MaxSim-Question-Pair
# 2018-Q1 1-21                  It looks like you guys had a very productive f...
#         2-34                  Where along that kind of 12% to 13% spectrum t...
#         3-14                  Okay, that's fair. And then, I just had a quic...
#         4-8                   Okay. Great. I'm sorry, I just, if I could sne...
#         6-19                  Just a couple of questions, so the sales shift...
#         7-26                  Okay. And then, thanks for sharing that $6 bil...
#         8-15                         Great. All right, well, good luck. Thanks.
#         9-9                   Hi, good afternoon, guys. Thanks for taking my...
#         10-32                 Impressive. John, did you give any detail betw...
#         11-37                                Okay, great. Thanks. Best of luck.
#         12-25                 Thanks for taking my questions. Well, just to ...
#         14-33                 So when we think of this $1.2 billion number y...
#         15-2                  So basically combined Q4 and Q1, sort of combi...
#         16-28                 Got you. So this is now where you've got to ju...
#         19-17                 I wonder if you can give us a sense. Are you f...
#         20-30                 Okay. That's good to know. And then on the Chi...
#         22-18                 Okay. 3Q 2019. Okay, good to know. Thanks. And...
#         23-4                  Okay. Good to know. Thanks for taking my quest...
#         24-0                  Hi, thanks. Maybe instead of focusing on the f...
#         25-35                 Thanks, David. That's really helpful. Can I al...
#         26-22                 Good afternoon, guys, and congrats on phenomen...
#         27-23                 That's great. That's phenomenal. And then on t...
#         28-7                  Okay. Very helpful. And then on inventories, i...
#         29-24                 That's great. And then lastly and last questio...
#         32-27                 Okay. So, I guess first, I just wanted to C Q1...
#         33-20                               Okay. And that's on a global basis?
#         35-5                  Okay, fair enough. John, maybe a question for ...
#         36-1                  Okay. So it's fair to say nothing that materia...
#         37-6                  Okay. Fair enough. And then just on China just...
#         38-13                 Okay. Final thing just real quick here. When I...
#         39-10                          Okay. Thank you very much. All the best.
#         40-16                 Hey, good afternoon, everyone. Thanks for taki...
#         41-3                  Right. So basically, your lowest gross margin ...
#         42-31                        All right. Thanks very much. Best of luck.
#         43-11                    Good afternoon. Thanks for taking my question.
#         44-12                 Hi. I just wanted to touch on some of the newe...
#         46-36                 Hey, thanks for fitting me back in. Just a cou...
#         49-29                 But I'm referring to how it comes against purc...
#
#                                                                  Question_Year2
# Year2   MaxSim-Question-Pair
# 2018-Q1 1-21                  Good afternoon. Thanks for taking my questions...
#         2-34                  And as far as visibility in the second quarter...
#         3-14                  Okay. And then just few quick follow-up questi...
#         4-8                   Thank you. And just lastly, could you just may...
#         6-19                  I understand that. Okay. So let's move on from...
#         7-26                  Should we think about that number as like in t...
#         8-15                              All right. Thanks guys. Best of luck.
#         9-9                   Have the comps held up as you got into Q2? Wha...
#         10-32                 Thank you very much. This is Westcott, on for ...
#         11-37                             Okay. Thank you very much. Good luck.
#         12-25                 Okay. Very helpful. And then last question. I ...
#         14-33                 And are you seeing a similar mix in your own s...
#         15-2                  Okay. That's helpful. So just one more. So it ...
#         16-28                 So on the rest of this year, though, have you ...
#         19-17                 All right. And sorry if I missed this, but did...
#         20-30                 Okay. And then on China, more specifically, yo...
#         22-18                 Thank you for taking my questions. Good aftern...
#         23-4                  Okay. Great. Thanks so much for taking my ques...
#         24-0                  Good afternoon. I wonder if you can just walk ...
#         25-35                 Yes, of course. And then your own retail store...
#         26-22                 Okay. Very helpful. And then on China, I think...
#         27-23                 Okay. Great. And then just a follow-up on Tom'...
#         28-7                  And with regard to the inventories, whereby yo...
#         29-24                 Okay. That's very helpful. And then the tax ra...
#         32-27                 Hi. Thanks for taking my question. So on the d...
#         33-20                 And then about the G&A when you knew it and li...
#         35-5                  Thanks for taking my questions. I guess just f...
#         36-1                  Okay. That's helpful. And then just as we are ...
#         37-6                  Could you maybe tell us how much China actuall...
#         38-13                 Again, just on the working capital side, that ...
#         39-10                             Okay. Thanks very much. All the best.
#         40-16                 Hi everybody. Thanks for taking my question. I...
#         41-3                  Okay. Good. And then leverage? Do you think le...
#         42-31                               All right. Thanks and best of luck.
#         43-11                 Hi. Good afternoon everybody. Thanks for takin...
#         44-12                 I think the SG&A dollar growth is obviously a ...
#         46-36                 Right and of course. And just one more. In loo...
#         49-29                    So that you will leverage distribution better?

# %%
skx_test.loc['2017-Q4', '2018-Q1', '29-24']['Question_Year1']
# Out:
# "That's great. And then lastly and last question here is on tax. I think you guys gave a nice range here of 12% to 17% for the year. Obviously, there's still a lack of visibility on what's going to happen further going forward. But at least for the first quarter, any kind of directional guidance on where we could think the tax rate can be for the quarter?"

# %%
skx_test.loc['2017-Q4', '2018-Q1', '29-24']['Question_Year2']
# Out:
# "Okay. That's very helpful. And then the tax rate cam in shy of 10%. Can you help us think about the puts and takes in terms of by quarter, should we think of the second quarter just to meaningful step up function to get to your full year tax rate range?"

# %%
skx_test.loc['2017-Q4', '2018-Q1', '44-12']['Question_Year1']
# Out:
# "Hi. I just wanted to touch on some of the newer international markets you've taken over in the last couple of years, Latin America and Korea. I know Korea is called out as one of the best growers. Overall, how are those doing? Did you start to see any margin improvement in fourth quarter? And how do you expect the margins in those businesses to trend next year?"

# %%
skx_test.loc['2017-Q4', '2018-Q1', '44-12']['Question_Year2']
# Out:
# "I think the SG&A dollar growth is obviously a point on the income statement that the sell-side has had trouble modeling in the past year or so. And it looks like the guidance implied for Q2 is pretty significant in terms of overall growth. You are now guiding to leverage, as I understand, in Q3. Can you just help us understand how you see SG&A dollar growth and SG&A rates progressing for the rest of the year? Because I think it's just creating a lot of volatility in terms of expectations. Thank you."
