# %%
import os
import spacy
import pickle
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from scipy.optimize import linear_sum_assignment
from tqdm import tqdm
from rich import print
from itertools import product

spacy.require_gpu()
NER = spacy.load("en_core_web_trf")

# %% [markdown]
# ## Format the DF

# %% [markdown]
# ### Simple Rule Functions

# %%
# 0. remove the question if it is too short (< 15 words)
def remove_too_short_question(txt, len_limit=15):
    return '' if len(txt.split()) < len_limit else txt
    
# 1. remove sentences if it is too short (< 5 words)
# def remove_too_short_first_sentence(txt, len_limit=10):
#     first_setence = txt.split('.')[0]
#     if len(first_setence.split()) < len_limit:
#         return '.'.join(txt.split('.')[1:])
#     else:
#         return txt
def remove_too_short_sentence_in_question(txt, len_limit=5):
    setences = txt.split('.')
    ret_setences = [cur_setence for cur_setence in setences if len(cur_setence.split()) >= len_limit]

    return '.'.join(ret_setences)

# 2. remove the setence if it contains thank you, good after noon, good morning, thank you very much, thanks
def remove_setence_contrains_special_words(txt, words_to_remove=['thank you', 'good afternoon', 'good morning', 'thank you very much', 'thanks', 'hey']):
    setences = txt.split('.')
    ret_setences = [cur_setence for cur_setence in setences if all(word not in cur_setence.lower() for word in words_to_remove)]

    return '.'.join(ret_setences)

# def identify_setence_contrains_special_words(txt, words_to_remove=['thank you', 'good afternoon', 'good morning', 'thank you very much', 'thanks']):
#     setences = txt.split('.')
#     for cur_setence in setences:
#         return any((word in cur_setence.lower() for word in words_to_remove))

# 3. remove the question if it is too long ( > 200 words)
def remove_too_long_question(txt, len_limit=200):
    return '' if len(txt.split()) >= len_limit else txt

# 4. replace all the name with 'Tim'
def replace_name_with(txt, replace_with_name='John'):
    parsed_txt = NER(txt)
    for word in parsed_txt.ents:
        if word.label_ == 'PERSON':
            txt = txt.replace(word.text, replace_with_name)
    return txt

# %% [markdown]
# ### Setences new parsed

# %%
setence_new_parsed = pd.read_csv(os.path.join(os.getcwd(), 'data', 'processed', 'Conf_transcripts_new_parsed_processed.csv'))
setence_new_parsed.head()
# Out:
# /tmp/ipykernel_6341/745358426.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   setence_new_parsed = pd.read_csv(os.path.join(os.getcwd(), 'data', 'processed', 'Conf_transcripts_new_parsed_processed.csv'))
#    question_index                          answeree  \
# 0               1  george paleologou, will kalutycz
# 1               2                     will kalutycz
# 2               3                     will kalutycz
# 3               5                 george paleologou
# 4               6                 george paleologou
#
#                                               answer     questioner  \
# 0  Yes, generally speaking, a lot of the rebalanc...   sabahat khan
# 1  Yes, it’s kind of a mixture, the Sandwich plan...   sabahat khan
# 2  Yes, again, I mean we deal in all commodities ...   sabahat khan
# 3                                     Thanks George.  george doumet
# 4  Yes, actually, it was more -- it was not too m...  george doumet
#
#                                             question  \
# 0  Thanks and good afternoon. Can you maybe talk ...
# 1  Alright, thanks. And then you mentioned that H...
# 2  Great. And then just if you could give us upda...
# 3  Hey, good afternoon guys and congrats on the q...
# 4  Just looking at Alberta first year-over-year g...
#
#                                            time_text equity quater  year
# 0  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017
# 1  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017
# 2  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017
# 3  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017
# 4  Premium Brands Holding Corp. (OTC:PRBZF) Q1 20...  PRBZF     Q1  2017

# %% [markdown]
# ### AAPL: (2018-Q1, 2018-Q2)

# %% [markdown]
# All Years

# %%
# years
np.sort(setence_new_parsed[setence_new_parsed['equity'] == 'AAPL'].year.unique())
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018], dtype=object)

# %% [markdown]
# Get only one year data

# %%
# subset
filter_equity = setence_new_parsed['equity'] == 'AAPL'
aapl_raw = setence_new_parsed[filter_equity]
filter_year = aapl_raw['year'].apply(lambda x: x in ['2018', 2018])
aapl_raw = aapl_raw[filter_year].copy()
print(aapl_raw.shape)
# Out:
# (27, 9)

# %% [markdown]
# Apply Rules to filter the data

# %%
aapl_raw['question'] = aapl_raw['question'].apply(remove_too_short_question)
aapl_raw = aapl_raw[aapl_raw['question'] != ''].copy()
aapl_raw = aapl_raw[aapl_raw['question'].apply(lambda x: x is not None)].copy()
print('Too short questions', aapl_raw.shape)
aapl_raw['question'] = aapl_raw['question'].apply(remove_too_long_question)
aapl_raw = aapl_raw[aapl_raw['question'] != ''].copy()
aapl_raw = aapl_raw[aapl_raw['question'].apply(lambda x: x is not None)].copy()
print('Too long questions', aapl_raw.shape)
aapl_raw['question'] = aapl_raw['question'].apply(remove_too_short_sentence_in_question).copy()
aapl_raw = aapl_raw[aapl_raw['question'] != ''].copy()
aapl_raw = aapl_raw[aapl_raw['question'].apply(lambda x: x is not None)].copy()
print('remove too short fist setences', aapl_raw.shape)
aapl_raw['question'] = aapl_raw['question'].apply(remove_setence_contrains_special_words).copy()
aapl_raw = aapl_raw[aapl_raw['question'] != ''].copy()
aapl_raw = aapl_raw[aapl_raw['question'].apply(lambda x: x is not None)].copy()
print('remove_setence_contrains_special_words', aapl_raw.shape)
aapl_raw['question'] = aapl_raw['question'].apply(replace_name_with).copy()
print('replace name', aapl_raw.shape)
aapl_raw['question'] = aapl_raw['question'].apply(remove_too_short_question)
aapl_raw = aapl_raw[aapl_raw['question'] != ''].copy()
aapl_raw = aapl_raw[aapl_raw['question'].apply(lambda x: x is not None)].copy()
print('Too short questions', aapl_raw.shape)
aapl_raw
# Out:
# Too short questions
# (25, 9)
# Too long questions
# (23, 9)
# remove too short fist setences
# (23, 9)
# remove_setence_contrains_special_words
# (23, 9)
# replace name
# (23, 9)
# Too short questions
# (23, 9)
#          question_index                              answeree  \
# 1857862               1     timothy donald cook - apple, inc.
# 1857863               3     timothy donald cook - apple, inc.
# 1857864               4     timothy donald cook - apple, inc.
# 1857865               5     timothy donald cook - apple, inc.
# 1857866               6     timothy donald cook - apple, inc.
# 1857869               9     timothy donald cook - apple, inc.
# 1857870              11     timothy donald cook - apple, inc.
# 1857871              13     timothy donald cook - apple, inc.
# 1858981               1                          luca maestri
# 1858982               2                               timcook
# 1858983               3                          luca maestri
# 1858984               4                          luca maestri
# 1858985               5                               timcook
# 1858986               6                               timcook
# 1858987               7                               timcook
# 1858988               8                luca maestri, tim cook
# 1858989               9                              tim cook
# 1858990              10                              tim cook
# 1858991              11                              tim cook
# 1858993              13                              tim cook
# 1858994              14                              tim cook
# 1858995              15                              tim cook
# 1858996              16  luca maestri, tim cook, nancy paxton
#
#                                                     answer  \
# 1857862  Sure. Shannon, it's Tim. As Luca mentioned ear...
# 1857863  Hi, Katy. It's Tim. The services grew 31%. We ...
# 1857864  Yeah, I think my own view is that China and th...
# 1857865  Well, Mike, it's Tim. Again, the great thing a...
# 1857866  It's a good question. iPhone X was the most po...
# 1857869  Yeah, good question. Let me start with India, ...
# 1857870  We price for the value that we're delivering, ...
# 1857871  Yeah, Jim, thanks for the question. In terms o...
# 1858981  Of course, we've been talking about the import...
# 1858982  The revenue growth from iPhone across all the ...
# 1858983  We are guiding to $62 billion. It's a strong d...
# 1858984  Let me walk you through the sequential first. ...
# 1858985  Mike, you did a good job of answering your que...
# 1858986  I see AR as being profound. I think, AR has th...
# 1858987  This is up to investors as to what things they...
# 1858988  Toni, on the tax rate, I will make two comment...
# 1858989  Laura, I missed the first part of that, you br...
# 1858990  Laura, you're cutting in and out. But I'm goin...
# 1858991  Well, that 1.4 billion, I don't know where tha...
# 1858993  What I said on the investor part is that I thi...
# 1858994  HomePod is an incredible product that is a unb...
# 1858995  Its a good question. Keep in mind that this ye...
# 1858996  Let me answer, Amit, starting with M&A. Our th...
#
#                                                 questioner  \
# 1857862              shannon s. cross - cross research llc
# 1857863    kathryn lynn huberty - morgan stanley & co. llc
# 1857864    kathryn lynn huberty - morgan stanley & co. llc
# 1857865             michael j. olson - piper jaffray & co.
# 1857866             michael j. olson - piper jaffray & co.
# 1857869  brian j. white - monness, crespi, hardt & co.,...
# 1857870  next we'll hear from wamsi mohan with bank of ...
# 1857871          jim suva - citigroup global markets, inc.
# 1858981                                      shannon cross
# 1858982                                      shannon cross
# 1858983                                       katy huberty
# 1858984                                       katy huberty
# 1858985                                         mike olson
# 1858986                                         mike olson
# 1858987                                    toni sacconaghi
# 1858988                                    toni sacconaghi
# 1858989                                       laura martin
# 1858990                                       laura martin
# 1858991                                       laura martin
# 1858993                                   steve milunovich
# 1858994                                   steve milunovich
# 1858995                                     amit daryanani
# 1858996                                     amit daryanani
#
#                                                   question  \
# 1857862   I wanted to ask about your thoughts on sort o...
# 1857863   The services growth acceleration is really th...
# 1857864  And it doesn't look like the threat of a trade...
# 1857865   Just following on the services question, I'd ...
# 1857866   And then any potential tariff issues aside, w...
# 1857869  Yes, John, I think there is China numbers are ...
# 1857870   Tim, can you comment on the price elasticity ...
# 1857871   And I'll ask actually both my questions at th...
# 1858981  John, I wanted to talk a little bit about, mor...
# 1858982  And then, John, maybe could you talk a little ...
# 1858983  Growing double-digits of such a large revenue ...
# 1858984   Just a follow-up on gross margin. Guidance fo...
# 1858985  I know you don't talk about future products, w...
# 1858986  And then how you're think about AR beyond iPho...
# 1858987  I have a question and follow-up. You commented...
# 1858988  And just a follow-up, maybe I could clarify tw...
# 1858989  3 billion devices you gave us, updating from t...
# 1858990  3 billion [technical difficulty] unique users ...
# 1858991  Yes, I was asking as a percent, the ownership....
# 1858993  John, you said you don't want to tell investor...
# 1858994  And could you address the positioning of HomeP...
# 1858995  I have two questions as well. Could you just t...
# 1858996  John, maybe a question for you. When you talke...
#
#                                                  time_text equity quater  year
# 1857862  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857863  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857864  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857865  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857866  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857869  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857870  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857871  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1858981  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858982  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858983  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858984  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858985  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858986  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858987  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858988  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858989  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858990  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858991  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858993  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858994  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858995  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858996  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018

# %% [markdown]
# Process index

# %%
# process index
for cur_query in tqdm(aapl_raw['time_text'].unique()):
    subset = aapl_raw[aapl_raw['time_text'] == cur_query]
    aapl_raw.loc[subset.index.tolist(), 'question_index'] = list(range(len(subset)))

print(aapl_raw['year'].unique())
print(aapl_raw['equity'].unique())
print(aapl_raw['quater'].unique())
aapl_raw
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 1007.40it/s]
# [2018]
# ['AAPL']
# ['Q2' 'Q1']
#          question_index                              answeree  \
# 1857862               0     timothy donald cook - apple, inc.
# 1857863               1     timothy donald cook - apple, inc.
# 1857864               2     timothy donald cook - apple, inc.
# 1857865               3     timothy donald cook - apple, inc.
# 1857866               4     timothy donald cook - apple, inc.
# 1857869               5     timothy donald cook - apple, inc.
# 1857870               6     timothy donald cook - apple, inc.
# 1857871               7     timothy donald cook - apple, inc.
# 1858981               0                          luca maestri
# 1858982               1                               timcook
# 1858983               2                          luca maestri
# 1858984               3                          luca maestri
# 1858985               4                               timcook
# 1858986               5                               timcook
# 1858987               6                               timcook
# 1858988               7                luca maestri, tim cook
# 1858989               8                              tim cook
# 1858990               9                              tim cook
# 1858991              10                              tim cook
# 1858993              11                              tim cook
# 1858994              12                              tim cook
# 1858995              13                              tim cook
# 1858996              14  luca maestri, tim cook, nancy paxton
#
#                                                     answer  \
# 1857862  Sure. Shannon, it's Tim. As Luca mentioned ear...
# 1857863  Hi, Katy. It's Tim. The services grew 31%. We ...
# 1857864  Yeah, I think my own view is that China and th...
# 1857865  Well, Mike, it's Tim. Again, the great thing a...
# 1857866  It's a good question. iPhone X was the most po...
# 1857869  Yeah, good question. Let me start with India, ...
# 1857870  We price for the value that we're delivering, ...
# 1857871  Yeah, Jim, thanks for the question. In terms o...
# 1858981  Of course, we've been talking about the import...
# 1858982  The revenue growth from iPhone across all the ...
# 1858983  We are guiding to $62 billion. It's a strong d...
# 1858984  Let me walk you through the sequential first. ...
# 1858985  Mike, you did a good job of answering your que...
# 1858986  I see AR as being profound. I think, AR has th...
# 1858987  This is up to investors as to what things they...
# 1858988  Toni, on the tax rate, I will make two comment...
# 1858989  Laura, I missed the first part of that, you br...
# 1858990  Laura, you're cutting in and out. But I'm goin...
# 1858991  Well, that 1.4 billion, I don't know where tha...
# 1858993  What I said on the investor part is that I thi...
# 1858994  HomePod is an incredible product that is a unb...
# 1858995  Its a good question. Keep in mind that this ye...
# 1858996  Let me answer, Amit, starting with M&A. Our th...
#
#                                                 questioner  \
# 1857862              shannon s. cross - cross research llc
# 1857863    kathryn lynn huberty - morgan stanley & co. llc
# 1857864    kathryn lynn huberty - morgan stanley & co. llc
# 1857865             michael j. olson - piper jaffray & co.
# 1857866             michael j. olson - piper jaffray & co.
# 1857869  brian j. white - monness, crespi, hardt & co.,...
# 1857870  next we'll hear from wamsi mohan with bank of ...
# 1857871          jim suva - citigroup global markets, inc.
# 1858981                                      shannon cross
# 1858982                                      shannon cross
# 1858983                                       katy huberty
# 1858984                                       katy huberty
# 1858985                                         mike olson
# 1858986                                         mike olson
# 1858987                                    toni sacconaghi
# 1858988                                    toni sacconaghi
# 1858989                                       laura martin
# 1858990                                       laura martin
# 1858991                                       laura martin
# 1858993                                   steve milunovich
# 1858994                                   steve milunovich
# 1858995                                     amit daryanani
# 1858996                                     amit daryanani
#
#                                                   question  \
# 1857862   I wanted to ask about your thoughts on sort o...
# 1857863   The services growth acceleration is really th...
# 1857864  And it doesn't look like the threat of a trade...
# 1857865   Just following on the services question, I'd ...
# 1857866   And then any potential tariff issues aside, w...
# 1857869  Yes, John, I think there is China numbers are ...
# 1857870   Tim, can you comment on the price elasticity ...
# 1857871   And I'll ask actually both my questions at th...
# 1858981  John, I wanted to talk a little bit about, mor...
# 1858982  And then, John, maybe could you talk a little ...
# 1858983  Growing double-digits of such a large revenue ...
# 1858984   Just a follow-up on gross margin. Guidance fo...
# 1858985  I know you don't talk about future products, w...
# 1858986  And then how you're think about AR beyond iPho...
# 1858987  I have a question and follow-up. You commented...
# 1858988  And just a follow-up, maybe I could clarify tw...
# 1858989  3 billion devices you gave us, updating from t...
# 1858990  3 billion [technical difficulty] unique users ...
# 1858991  Yes, I was asking as a percent, the ownership....
# 1858993  John, you said you don't want to tell investor...
# 1858994  And could you address the positioning of HomeP...
# 1858995  I have two questions as well. Could you just t...
# 1858996  John, maybe a question for you. When you talke...
#
#                                                  time_text equity quater  year
# 1857862  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857863  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857864  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857865  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857866  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857869  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857870  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1857871  Apple, Inc. (NASDAQ:AAPL) Q2 2018 Earnings Cal...   AAPL     Q2  2018
# 1858981  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858982  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858983  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858984  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858985  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858986  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858987  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858988  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858989  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858990  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858991  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858993  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858994  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858995  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018
# 1858996  Apple, Inc. (NASDAQ:AAPL) Q1 2018 Earnings Con...   AAPL     Q1  2018

# %% [markdown]
# Format

# %%
# format
aapl = pd.DataFrame(
    {
        "fyear": aapl_raw.apply(
            lambda x: str(x["year"]) + "-" + str(x["quater"]), axis=1
        ),
        "pid": aapl_raw["question_index"],
        "text": aapl_raw["question"],
    }
)
aapl.reset_index(drop=True, inplace=True)
aapl
# Out:
#       fyear  pid                                               text
# 0   2018-Q2    0   I wanted to ask about your thoughts on sort o...
# 1   2018-Q2    1   The services growth acceleration is really th...
# 2   2018-Q2    2  And it doesn't look like the threat of a trade...
# 3   2018-Q2    3   Just following on the services question, I'd ...
# 4   2018-Q2    4   And then any potential tariff issues aside, w...
# 5   2018-Q2    5  Yes, John, I think there is China numbers are ...
# 6   2018-Q2    6   Tim, can you comment on the price elasticity ...
# 7   2018-Q2    7   And I'll ask actually both my questions at th...
# 8   2018-Q1    0  John, I wanted to talk a little bit about, mor...
# 9   2018-Q1    1  And then, John, maybe could you talk a little ...
# 10  2018-Q1    2  Growing double-digits of such a large revenue ...
# 11  2018-Q1    3   Just a follow-up on gross margin. Guidance fo...
# 12  2018-Q1    4  I know you don't talk about future products, w...
# 13  2018-Q1    5  And then how you're think about AR beyond iPho...
# 14  2018-Q1    6  I have a question and follow-up. You commented...
# 15  2018-Q1    7  And just a follow-up, maybe I could clarify tw...
# 16  2018-Q1    8  3 billion devices you gave us, updating from t...
# 17  2018-Q1    9  3 billion [technical difficulty] unique users ...
# 18  2018-Q1   10  Yes, I was asking as a percent, the ownership....
# 19  2018-Q1   11  John, you said you don't want to tell investor...
# 20  2018-Q1   12  And could you address the positioning of HomeP...
# 21  2018-Q1   13  I have two questions as well. Could you just t...
# 22  2018-Q1   14  John, maybe a question for you. When you talke...

# %% [markdown]
# ### SKX: (2018-Q1, 2018-Q2)

# %% [markdown]
# All Years

# %%
# years
np.sort(setence_new_parsed[setence_new_parsed['equity'] == 'SKX'].year.unique())
# Out:
# array(['2007', '2008', '2009', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018'], dtype=object)

# %% [markdown]
# Get only one year data

# %%
# subset
filter_equity = setence_new_parsed['equity'] == 'SKX'
skx_raw = setence_new_parsed[filter_equity]
filter_year = skx_raw['year'].apply(lambda x: x in ['2017', 2017])
skx_raw = skx_raw[filter_year].copy()
filter_quater = skx_raw['quater'].apply(lambda x: x in ['Q3', 'Q4'])
skx_raw = skx_raw[filter_quater].copy()
print(skx_raw.shape)
skx_raw
# Out:
# (111, 9)
#       question_index                                           answeree  \
# 2988               1                david weinberg - skechers usa, inc.
# 2989               2                david weinberg - skechers usa, inc.
# 2990               3                david weinberg - skechers usa, inc.
# 2991               4  david weinberg - skechers usa, inc., john m. v...
# 2992               5             john m. vandemore - skechers usa, inc.
# ...              ...                                                ...
# 3407              52                                     david weinberg
# 3408              53                                     david weinberg
# 3409              54                                     david weinberg
# 3410              55                                     david weinberg
# 3411              56                                     david weinberg
#
#                                                  answer  \
# 2988                                                Hi.
# 2989  Yeah, I think it's fair to say that we think w...
# 2990  You know, that's very difficult because we're ...
# 2991  So, I'll start with the repurchase. Obviously ...
# 2992  We're not giving international percentages. I ...
# ...                                                 ...
# 3407                                            Thanks.
# 3408                                            No, no.
# 3409  No, because I want to get down to the detail. ...
# 3410  It's doing very well. It's probably heading th...
# 3411                                      Okay. Thanks.
#
#                                              questioner  \
# 2988  corinna van der ghinst - citigroup global mark...
# 2989  corinna van der ghinst - citigroup global mark...
# 2990  corinna van der ghinst - citigroup global mark...
# 2991  corinna van der ghinst - citigroup global mark...
# 2992  corinna van der ghinst - citigroup global mark...
# ...                                                 ...
# 3407                                          tom nikic
# 3408                                          sam poser
# 3409                                          sam poser
# 3410                                          sam poser
# 3411                                          sam poser
#
#                                                question  \
# 2988                  Hi. Hi David and welcome to John.
# 2989  It looks like you guys had a very productive f...
# 2990  Where along that kind of 12% to 13% spectrum t...
# 2991  Okay, that's fair. And then, I just had a quic...
# 2992  Okay. Great. I'm sorry, I just, if I could sne...
# ...                                                 ...
# 3407  All right, all right, thanks, David, good luck...
# 3408  Two questions, real quick, the domestic backlo...
# 3409                     Well, can you give us a range?
# 3410  Okay. Thank you. Then secondly, there are some...
# 3411        Thanks, and again, [indiscernible] success.
#
#                                               time_text equity quater  year
# 2988  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2989  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2990  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2991  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2992  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# ...                                                 ...    ...    ...   ...
# 3407  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3408  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3409  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3410  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3411  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
#
# [111 rows x 9 columns]

# %% [markdown]
# Appply rules to filter the data

# %%
skx_raw['question'] = skx_raw['question'].apply(remove_too_short_question)
skx_raw = skx_raw[skx_raw['question'] != ''].copy()
skx_raw = skx_raw[skx_raw['question'].apply(lambda x: x is not None)].copy()
print('Too short questions', skx_raw.shape)
skx_raw['question'] = skx_raw['question'].apply(remove_too_long_question)
skx_raw = skx_raw[skx_raw['question'] != ''].copy()
skx_raw = skx_raw[skx_raw['question'].apply(lambda x: x is not None)].copy()
print('Too long questions', skx_raw.shape)
skx_raw['question'] = skx_raw['question'].apply(remove_too_short_sentence_in_question).copy()
skx_raw = skx_raw[skx_raw['question'] != ''].copy()
skx_raw = skx_raw[skx_raw['question'].apply(lambda x: x is not None)].copy()
print('remove too short fist setences', skx_raw.shape)
skx_raw['question'] = skx_raw['question'].apply(remove_setence_contrains_special_words).copy()
skx_raw = skx_raw[skx_raw['question'] != ''].copy()
skx_raw = skx_raw[skx_raw['question'].apply(lambda x: x is not None)].copy()
print('remove_setence_contrains_special_words', skx_raw.shape)
skx_raw['question'] = skx_raw['question'].apply(replace_name_with).copy()
print('replace name', skx_raw.shape)
skx_raw['question'] = skx_raw['question'].apply(remove_too_short_question)
skx_raw = skx_raw[skx_raw['question'] != ''].copy()
skx_raw = skx_raw[skx_raw['question'].apply(lambda x: x is not None)].copy()
print('Too short questions', skx_raw.shape)
skx_raw
# Out:
# Too short questions
# (73, 9)
# Too long questions
# (73, 9)
# remove too short fist setences
# (73, 9)
# remove_setence_contrains_special_words
# (72, 9)
# replace name
# (72, 9)
# Too short questions
# (69, 9)
#       question_index                                           answeree  \
# 2989               2                david weinberg - skechers usa, inc.
# 2990               3                david weinberg - skechers usa, inc.
# 2991               4  david weinberg - skechers usa, inc., john m. v...
# 2992               5             john m. vandemore - skechers usa, inc.
# 2995               9                david weinberg - skechers usa, inc.
# ...              ...                                                ...
# 3404              49                                     david weinberg
# 3405              50                                     david weinberg
# 3406              51                                     david weinberg
# 3408              53                                     david weinberg
# 3410              55                                     david weinberg
#
#                                                  answer  \
# 2989  Yeah, I think it's fair to say that we think w...
# 2990  You know, that's very difficult because we're ...
# 2991  So, I'll start with the repurchase. Obviously ...
# 2992  We're not giving international percentages. I ...
# 2995  Yeah. I think the biggest piece of the portfol...
# ...                                                 ...
# 3404  I think it's most to do with the softness in t...
# 3405                                               Yes.
# 3406  No, I mean, that will come out in the Q. So I ...
# 3408                                            No, no.
# 3410  It's doing very well. It's probably heading th...
#
#                                              questioner  \
# 2989  corinna van der ghinst - citigroup global mark...
# 2990  corinna van der ghinst - citigroup global mark...
# 2991  corinna van der ghinst - citigroup global mark...
# 2992  corinna van der ghinst - citigroup global mark...
# 2995  scott d. krasik - the buckingham research grou...
# ...                                                 ...
# 3404                                          tom nikic
# 3405                                          tom nikic
# 3406                                          tom nikic
# 3408                                          sam poser
# 3410                                          sam poser
#
#                                                question  \
# 2989  It looks like you guys had a very productive f...
# 2990  Where along that kind of 12% to 13% spectrum t...
# 2991   And then, I just had a quick follow-up on you...
# 2992   I'm sorry, I just, if I could sneak in one fo...
# 2995  Just a couple of questions, so the sales shift...
# ...                                                 ...
# 3404  All right, I have a question about the U. You ...
# 3405  Right, right, I just meant would the growth ra...
# 3406   Okay, and sorry if I missed this. Did you by ...
# 3408  Two questions, real quick, the domestic backlo...
# 3410   Then secondly, there are some new styles that...
#
#                                               time_text equity quater  year
# 2989  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2990  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2991  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2992  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2995  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# ...                                                 ...    ...    ...   ...
# 3404  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3405  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3406  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3408  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3410  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
#
# [69 rows x 9 columns]

# %% [markdown]
# Process Index

# %%
# process index
for cur_query in tqdm(skx_raw['year'].unique()):
    subset1 = skx_raw[skx_raw['year'] == cur_query]
    for cur_query2 in subset1['quater'].unique():
        subset2 = subset1[subset1['quater'] == cur_query2]
        skx_raw.loc[subset2.index.tolist(), 'question_index'] = list(range(len(subset2)))

print(skx_raw['year'].unique())
print(skx_raw['equity'].unique())
print(skx_raw['quater'].unique())
print(len(skx_raw))
skx_raw.head(5)
skx_raw
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 328.94it/s]
# ['2017']
# ['SKX']
# ['Q4' 'Q3']
# 69
#       question_index                                           answeree  \
# 2989               0                david weinberg - skechers usa, inc.
# 2990               1                david weinberg - skechers usa, inc.
# 2991               2  david weinberg - skechers usa, inc., john m. v...
# 2992               3             john m. vandemore - skechers usa, inc.
# 2995               4                david weinberg - skechers usa, inc.
# ...              ...                                                ...
# 3404              28                                     david weinberg
# 3405              29                                     david weinberg
# 3406              30                                     david weinberg
# 3408              31                                     david weinberg
# 3410              32                                     david weinberg
#
#                                                  answer  \
# 2989  Yeah, I think it's fair to say that we think w...
# 2990  You know, that's very difficult because we're ...
# 2991  So, I'll start with the repurchase. Obviously ...
# 2992  We're not giving international percentages. I ...
# 2995  Yeah. I think the biggest piece of the portfol...
# ...                                                 ...
# 3404  I think it's most to do with the softness in t...
# 3405                                               Yes.
# 3406  No, I mean, that will come out in the Q. So I ...
# 3408                                            No, no.
# 3410  It's doing very well. It's probably heading th...
#
#                                              questioner  \
# 2989  corinna van der ghinst - citigroup global mark...
# 2990  corinna van der ghinst - citigroup global mark...
# 2991  corinna van der ghinst - citigroup global mark...
# 2992  corinna van der ghinst - citigroup global mark...
# 2995  scott d. krasik - the buckingham research grou...
# ...                                                 ...
# 3404                                          tom nikic
# 3405                                          tom nikic
# 3406                                          tom nikic
# 3408                                          sam poser
# 3410                                          sam poser
#
#                                                question  \
# 2989  It looks like you guys had a very productive f...
# 2990  Where along that kind of 12% to 13% spectrum t...
# 2991   And then, I just had a quick follow-up on you...
# 2992   I'm sorry, I just, if I could sneak in one fo...
# 2995  Just a couple of questions, so the sales shift...
# ...                                                 ...
# 3404  All right, I have a question about the U. You ...
# 3405  Right, right, I just meant would the growth ra...
# 3406   Okay, and sorry if I missed this. Did you by ...
# 3408  Two questions, real quick, the domestic backlo...
# 3410   Then secondly, there are some new styles that...
#
#                                               time_text equity quater  year
# 2989  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2990  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2991  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2992  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# 2995  SKECHERS USA, Inc. (NYSE:SKX) Q4 2017 Earnings...    SKX     Q4  2017
# ...                                                 ...    ...    ...   ...
# 3404  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3405  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3406  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3408  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
# 3410  Skechers USA (NYSE:SKX) Q3 2017 Earnings Confe...    SKX     Q3  2017
#
# [69 rows x 9 columns]

# %% [markdown]
# Format

# %%
# format
skx = pd.DataFrame(
    {
        "fyear": skx_raw.apply(
            lambda x: str(x["year"]) + "-" + str(x["quater"]), axis=1
        ),
        "pid": skx_raw["question_index"],
        "text": skx_raw["question"],
    }
)
skx.reset_index(drop=True, inplace=True)
skx
# Out:
#       fyear  pid                                               text
# 0   2017-Q4    0  It looks like you guys had a very productive f...
# 1   2017-Q4    1  Where along that kind of 12% to 13% spectrum t...
# 2   2017-Q4    2   And then, I just had a quick follow-up on you...
# 3   2017-Q4    3   I'm sorry, I just, if I could sneak in one fo...
# 4   2017-Q4    4  Just a couple of questions, so the sales shift...
# ..      ...  ...                                                ...
# 64  2017-Q3   28  All right, I have a question about the U. You ...
# 65  2017-Q3   29  Right, right, I just meant would the growth ra...
# 66  2017-Q3   30   Okay, and sorry if I missed this. Did you by ...
# 67  2017-Q3   31  Two questions, real quick, the domestic backlo...
# 68  2017-Q3   32   Then secondly, there are some new styles that...
#
# [69 rows x 3 columns]

# %% [markdown]
# ## Calculate the pairwise similarity

# %% [markdown]
# ### Setence Embedding Function

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ### Similarity Calculation Function

# %%
def compute_two_doc_sim(doc1_emb, doc2_emb):
    sim = np.dot(doc1_emb, doc2_emb.T)
    sim = (sim + 1) / 2
    return sim

def format_index_score(sim_score):
    iter_index = product(range(sim_score.shape[0]), range(sim_score.shape[1]))
    return [(i, j, sim_score[i, j]) for i, j in iter_index]

def compute_sim(df, bert_model):
    result = {}
    years = np.sort(df.fyear.unique())
    embeddings = bert_model.encode(
        df.text.tolist(),
        convert_to_tensor=False,
        normalize_embeddings=True,
        convert_to_numpy=True,
    )
    for i in range(len(years) - 1):
        temp_dict = {}
        for j in range(i + 1, len(years)):
            doc1_index = df[df.fyear == years[i]].index.tolist()
            doc2_index = df[df.fyear == years[j]].index.tolist()
            doc1 = embeddings[doc1_index]
            doc2 = embeddings[doc2_index]
            sim = compute_two_doc_sim(doc1, doc2)
            temp_dict[years[j]] = format_index_score(sim)
        result[years[i]] = temp_dict
    return result

# post process funcs
def pair_dict(listOflist):
    temp_dict = {}
    for i in listOflist:
        pair_name = f'{str(i[0])}-{str(i[1])}'
        temp_dict[pair_name] = i[2:]
    return temp_dict

def post_process_df(m):
    # add another layer
    for key in m:
        cur_dict = m.get(key)
        for key2 in cur_dict.keys():
            cur_dict[key2] = pair_dict(cur_dict.get(key2))
    # prepare multi-index
    tuple_list = []
    for key in m:
        cur_dict = m.get(key)
        for key2 in cur_dict.keys():
            tuple_list.extend((key, key2, key3) for key3 in cur_dict.get(key2).keys())
    index = pd.MultiIndex.from_tuples(tuple_list, names=["Year1", "Year2", "MaxSim-Question-Pair"])
    # get similarity score
    similarity_score = []
    for key in m:
        cur_dict = m.get(key)
        for key2 in cur_dict.keys():
            similarity_score.extend(cur_dict.get(key2).get(key3)[0] for key3 in cur_dict.get(key2).keys())

    return pd.DataFrame({'Similarity Score': similarity_score}, index=index)

# search text
def search_text(the_df, search_df):
    try:
        search_df = search_df.copy()
        the_df = the_df.copy()
        question_from_1 = []
        question_from_2 = []
        for index, row in tqdm(the_df.iterrows()):
            # unpack
            year1, year2, question_pair = index
            year1, year1_quater = year1.split("-")
            year2, year2_quater = year2.split("-")
            question_1_index, question_2_index = question_pair.split("-")
            # locate question 1
            year_filter = search_df['year'].apply(lambda x: x in [year1, int(year1)])
            question_1 = search_df[
                year_filter
                & (search_df["quater"] == year1_quater)
                & (search_df["question_index"] == int(question_1_index))
            ]["question"]
            question_from_1.append(question_1.iloc[0])
            # locate question 2
            year_filter = search_df['year'].apply(lambda x: x in [year2, int(year2)])
            question_2 = search_df[
                year_filter
                & (search_df["quater"] == year2_quater)
                & (search_df["question_index"] == int(question_2_index))
            ]["question"]
            question_from_2.append(question_2.iloc[0])
        the_df["Question_Year1"] = question_from_1
        the_df["Question_Year2"] = question_from_2
    except IndexError:
        print(year1, year2, year1_quater, year2_quater, question_1_index, question_2_index)
    
    return the_df

# %% [markdown]
# ### Compuate Similarity AAPL

# %%
aapl_sim = compute_sim(aapl, model)
aapl_sim = post_process_df(aapl_sim)
aapl_sim = search_text(aapl_sim, aapl_raw)
# Out:
# 120it [00:00, 697.52it/s]

# %%
aapl_sim.loc['2018-Q1'][:10]
# Out:
#                               Similarity Score  \
# Year2   MaxSim-Question-Pair
# 2018-Q2 0-0                           0.600629
#         0-1                           0.611807
#         0-2                           0.559650
#         0-3                           0.564583
#         0-4                           0.600771
#         0-5                           0.571988
#         0-6                           0.566988
#         0-7                           0.666451
#         1-0                           0.785688
#         1-1                           0.609269
#
#                                                                  Question_Year1  \
# Year2   MaxSim-Question-Pair
# 2018-Q2 0-0                   John, I wanted to talk a little bit about, mor...
#         0-1                   John, I wanted to talk a little bit about, mor...
#         0-2                   John, I wanted to talk a little bit about, mor...
#         0-3                   John, I wanted to talk a little bit about, mor...
#         0-4                   John, I wanted to talk a little bit about, mor...
#         0-5                   John, I wanted to talk a little bit about, mor...
#         0-6                   John, I wanted to talk a little bit about, mor...
#         0-7                   John, I wanted to talk a little bit about, mor...
#         1-0                   And then, John, maybe could you talk a little ...
#         1-1                   And then, John, maybe could you talk a little ...
#
#                                                                  Question_Year2
# Year2   MaxSim-Question-Pair
# 2018-Q2 0-0                    I wanted to ask about your thoughts on sort o...
#         0-1                    The services growth acceleration is really th...
#         0-2                   And it doesn't look like the threat of a trade...
#         0-3                    Just following on the services question, I'd ...
#         0-4                    And then any potential tariff issues aside, w...
#         0-5                   Yes, John, I think there is China numbers are ...
#         0-6                    Tim, can you comment on the price elasticity ...
#         0-7                    And I'll ask actually both my questions at th...
#         1-0                    I wanted to ask about your thoughts on sort o...
#         1-1                    The services growth acceleration is really th...

# %%
with open(os.path.join(os.getcwd(), 'data', 'result', 'pairwise_similarity', 'aapl_sim.pkl'), 'wb') as f:
    pickle.dump(aapl_sim, f)
aapl_sim.to_csv(os.path.join(os.getcwd(), 'data', 'result', 'pairwise_similarity', 'aapl_sim.csv'))

# %% [markdown]
# ### Compute Similarity SKX

# %%
skx_sim = compute_sim(skx, model)
skx_sim = post_process_df(skx_sim)
skx_sim = search_text(skx_sim, skx_raw)
# Out:
# 1188it [00:01, 831.47it/s]

# %%
skx_sim
# Out:
#                                       Similarity Score  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q3 2017-Q4 0-0                           0.815662
#                 0-1                           0.622075
#                 0-2                           0.678226
#                 0-3                           0.693569
#                 0-4                           0.663784
# ...                                                ...
#                 32-31                         0.672904
#                 32-32                         0.577031
#                 32-33                         0.511471
#                 32-34                         0.572161
#                 32-35                         0.568291
#
#                                                                          Question_Year1  \
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q3 2017-Q4 0-0                   I was hoping to start with just the operating ...
#                 0-1                   I was hoping to start with just the operating ...
#                 0-2                   I was hoping to start with just the operating ...
#                 0-3                   I was hoping to start with just the operating ...
#                 0-4                   I was hoping to start with just the operating ...
# ...                                                                                 ...
#                 32-31                  Then secondly, there are some new styles that...
#                 32-32                  Then secondly, there are some new styles that...
#                 32-33                  Then secondly, there are some new styles that...
#                 32-34                  Then secondly, there are some new styles that...
#                 32-35                  Then secondly, there are some new styles that...
#
#                                                                          Question_Year2
# Year1   Year2   MaxSim-Question-Pair
# 2017-Q3 2017-Q4 0-0                   It looks like you guys had a very productive f...
#                 0-1                   Where along that kind of 12% to 13% spectrum t...
#                 0-2                    And then, I just had a quick follow-up on you...
#                 0-3                    I'm sorry, I just, if I could sneak in one fo...
#                 0-4                   Just a couple of questions, so the sales shift...
# ...                                                                                 ...
#                 32-31                  I just wanted to touch on some of the newer i...
#                 32-32                  And then, last quarter you talked a little bi...
#                 32-33                  And then what sort of comps do you have embed...
#                 32-34                 Well, given all these changes with buybacks an...
#                 32-35                 But I'm referring to how it comes against purc...
#
# [1188 rows x 3 columns]

# %%
with open(os.path.join(os.getcwd(), 'data', 'result', 'pairwise_similarity', 'skx_sim.pkl'), 'wb') as f:
    pickle.dump(skx_sim, f)
skx_sim.to_csv(os.path.join(os.getcwd(), 'data', 'result', 'pairwise_similarity', 'skx_sim.csv'))
